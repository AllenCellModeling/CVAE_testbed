# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy
import torch
import pandas as pd

# %%
from CVAE_testbed.utils.compare_plots import compare_plots_best_performing, plot_single_model_multiple_epoch, plot_multiple_model_multiple_epoch

    
# paths_to_compare = ["/home/ritvik.vasan/Github/cookiecutter/CVAE_testbed/scripts/outputs/aics_features/159_features/new/2019:09:06:11:38:11/",
#                     "/home/ritvik.vasan/Github/cookiecutter/CVAE_testbed/scripts/outputs/aics_features/159_features/new/2019:09:06:11:38:21/",
#                     "/home/ritvik.vasan/Github/cookiecutter/CVAE_testbed/scripts/outputs/aics_features/159_features/new/2019:09:06:11:38:32/",
#                     "/home/ritvik.vasan/Github/cookiecutter/CVAE_testbed/scripts/outputs/aics_features/159_features/new/2019:09:06:11:38:44/",
#                     "/home/ritvik.vasan/Github/cookiecutter/CVAE_testbed/scripts/outputs/aics_features/159_features/new/2019:09:06:11:38:55/"
#                     ]
                    
    
# paths_to_compare = ["/home/ritvik.vasan/Github/cookiecutter/CVAE_testbed/scripts/outputs/aics_features/102_features/2019:09:06:12:50:22/",
#                     "/home/ritvik.vasan/Github/cookiecutter/CVAE_testbed/scripts/outputs/aics_features/102_features/2019:09:06:12:50:29/",
#                     "/home/ritvik.vasan/Github/cookiecutter/CVAE_testbed/scripts/outputs/aics_features/102_features/2019:09:06:12:50:37/",
#                     "/home/ritvik.vasan/Github/cookiecutter/CVAE_testbed/scripts/outputs/aics_features/102_features/2019:09:06:12:50:46/",
#                     "/home/ritvik.vasan/Github/cookiecutter/CVAE_testbed/scripts/outputs/aics_features/102_features/2019:09:06:12:50:54/"
#                     ]


#"/home/ritvik.vasan/Github/cookiecutter/CVAE_testbed/scripts/outputs/aics_features/159_features/new2/2019:09:06:12:47:55/"
paths_to_compare = ["/home/ritvik.vasan/Github/cookiecutter/CVAE_testbed/scripts/outputs/aics_features/159_features/new2/2019:09:06:12:48:06/",
                    "/home/ritvik.vasan/Github/cookiecutter/CVAE_testbed/scripts/outputs/aics_features/159_features/new2/2019:09:06:12:48:45/",
                    "/home/ritvik.vasan/Github/cookiecutter/CVAE_testbed/scripts/outputs/aics_features/159_features/new2/2019:09:08:10:53:57/",
                    "/home/ritvik.vasan/Github/cookiecutter/CVAE_testbed/scripts/outputs/aics_features/159_features/new2/2019:09:08:10:53:39/",
                    "/home/ritvik.vasan/Github/cookiecutter/CVAE_testbed/scripts/outputs/aics_features/159_features/new2/2019:09:06:12:48:58/",
                    "/home/ritvik.vasan/Github/cookiecutter/CVAE_testbed/scripts/outputs/aics_features/159_features/new2/2019:09:08:10:37:33/",
                    "/home/ritvik.vasan/Github/cookiecutter/CVAE_testbed/scripts/outputs/aics_features/159_features/new2/2019:09:06:12:49:10/",
                    ]

# %% [markdown]
# # Compare models during train + test

# %%
csv = {'save_dir': [], 'csv_path': []}

for j in range(len(paths_to_compare)):
    csv['save_dir'].append(paths_to_compare[j])
    csv['csv_path'].append(csv['save_dir'][j] + "costs.csv")

# Plot KLD vs MSE for multiple models and numbers of conditions
compare_plots_best_performing(csv)

# Plot KLD vs MSE for multiple models, numbers of conditions and epochs
plot_multiple_model_multiple_epoch(csv)

# CHOOSE SINGLE CSV
single_csv = {'save_dir': csv['save_dir'][0], 'csv_path': csv['csv_path'][0]}

# Plot KLD vs MSE for multiple number of conditions and epochs for a single model
# plot_single_model_multiple_epoch(single_csv)

# %% [markdown]
# # Compare model looks during encoding test

# %%
# paths_to_compare = ["~/Github/cookiecutter/CVAE_testbed/scripts/outputs/aics_features/102_features/2019:09:04:14:57:51/", 
#                     "~/Github/cookiecutter/CVAE_testbed/scripts/outputs/aics_features/102_features/2019:09:04:14:58:14/",
#                     "~/Github/cookiecutter/CVAE_testbed/scripts/outputs/aics_features/102_features/2019:09:04:14:58:04/",
#                     "~/Github/cookiecutter/CVAE_testbed/scripts/outputs/aics_features/102_features/2019:09:04:14:58:33/"]


# paths_to_compare = ["~/Github/cookiecutter/CVAE_testbed/scripts/outputs/aics_features/159_features/2019:09:04:21:08:39/", 
#                     "~/Github/cookiecutter/CVAE_testbed/scripts/outputs/aics_features/159_features/2019:09:04:21:10:37/",
#                     "~/Github/cookiecutter/CVAE_testbed/scripts/outputs/aics_features/159_features/2019:09:04:21:09:00/",
#                     "~/Github/cookiecutter/CVAE_testbed/scripts/outputs/aics_features/159_features/2019:09:04:21:10:14/"]

# %%
from CVAE_testbed.utils.compare_plots import compare_plots_best_performing_encoding

# %%
csv = {'save_dir': [], 'csv_path': []}
for j in range(len(paths_to_compare)):
    csv['save_dir'].append(paths_to_compare[j])
    csv['csv_path'].append(csv['save_dir'][j] + "encoding_kl_vs_rcl.csv")


compare_plots_best_performing_encoding(csv)

# %% [markdown]
# # Compare models for ELBO/FID vs beta

# %%
from CVAE_testbed.utils.compare_plots import compare_plots_beta

# %%
csv = {'save_dir': [], 'csv_path_1': [], 'csv_path_2': []}
for j in range(len(paths_to_compare)):
    csv['save_dir'].append(paths_to_compare[j])
    csv['csv_path_1'].append(csv['save_dir'][j] + "encoding_kl_vs_rcl.csv")
    csv['csv_path_2'].append(csv['save_dir'][j] + "fid_data.csv")
    

compare_plots_beta(csv)

# %%
import numpy as np
kld_per_dim = pd.pivot_table(csv_df, values='kl_divergence', index='popped_cond', columns = 'latent_dim', aggfunc=np.mean)

rcl_per_dim = pd.pivot_table(csv_df, values='rcl', index='popped_cond', columns = 'latent_dim', aggfunc=np.mean)

elbo_per_dim = pd.pivot_table(csv_df, values='elbo', index='popped_cond', columns = 'latent_dim', aggfunc=np.mean)

# %%
import numpy as np
kld_per_dim = pd.pivot_table(csv_df, values='elbo', index='popped_cond', columns = 'latent_dim', aggfunc=np.mean)
sns.heatmap(data = kld_per_dim, cmap = 'viridis')

# %%
import numpy as np
kld_per_dim = pd.pivot_table(csv_df, values='kl_divergence', index='num_conds', columns = 'popped_cond', aggfunc=np.mean)
sns.heatmap(data = kld_per_dim, cmap = 'viridis', xticklabels = False)

# %%
csv_df = pd.read_csv(csv['csv_path'][j])

# %%
for i in set(csv_df['popped_cond']):
    print(i)
# Out:
# 62
# 35
# 4
# 95
# 53
# 10
# 0
# 8
# 27
# 5
# 28
# 50
# 54
# 48
# []
# 22
# 12
# 24
# 14
# 51
# 25
# 20
# 96
# 33
# 17
# 38
# 15
# 11
# 16
# 67
# 26
# 3
# 73
# 9
# 68
# 76
# 36
# 2
# 1
# 45
# 69
# 18
# 7
# 52
# 21
# 13
# 47
# 19

# %%
data = {'a': [], 'b': []}
data['a'].append(1)
data['b'].append(None)

# %%
data['a'].append(1)
data['b'].append(None)

# %%
c = pd.DataFrame(data)

# %%
if all(pd.isna(c['a'])):
       print('yes')

# %%
import seaborn as sns

sns.lineplot(data = csv_df, x = 'latent_dim', y = 'kl_divergence', hue = 'num_conds', legend=False)
# sns.lineplot(data = csv_df, x = 'num_conds', y = 'elbo', hue ='cond_comb')

# %%
# csv_df.sort_values(by='elbo', ascending=False, inplace=True)
sns.lineplot(data = csv_df, x = 'latent_dim', y = 'kl_divergence', hue = 'popped_cond', legend=False)

# %%
csv_df
# Out:
#        Unnamed: 0  latent_dim  kl_divergence  num_conds popped_cond  \
# 283           283         283       1.229295          0          []
# 168           168         168       1.186040          0          []
# 166           166         166       1.161885          0          []
# 303           303         303       1.148263          0          []
# 492           492         492       1.071057          0          []
# 482           482         482       0.927070          0          []
# 98             98          98       0.879399          0          []
# 136           136         136       0.843549          0          []
# 32             32          32       0.835370          0          []
# 108           108         108       0.807136          0          []
# 125           125         125       0.772571          0          []
# 26             26          26       0.754392          0          []
# 30             30          30       0.747523          0          []
# ...
